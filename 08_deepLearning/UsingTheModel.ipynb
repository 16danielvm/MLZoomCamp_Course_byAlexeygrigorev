# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.models.load_model('xception_v4_1_08_0.883.h5')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.xception import preprocess_input

# %%
test_gen = ImageDataGenerator(preprocessing_function= preprocess_input)

test_ds = test_gen.flow_from_directory(
    './clothing-dataset-small-master/validation',
    target_size = (150,150),
    batch_size = 16,
    shuffle = False
)
# Out:
# Found 341 images belonging to 10 classes.

# %%
model.evaluate(test_ds)
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-19-cf7953a05327> in <module>
# ----> 1 model.evaluate(test_ds)
#
# c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# UnimplementedError: Graph execution error:
#
# Detected at node 'model_7/xception/block1_conv1/Conv2D' defined at (most recent call last):
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\runpy.py", line 193, in _run_module_as_main
#       "__main__", mod_spec)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\runpy.py", line 85, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\traitlets\config\application.py", line 664, in launch_instance
#       app.start()
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelapp.py", line 597, in start
#       self.io_loop.start()
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\platform\asyncio.py", line 149, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\asyncio\base_events.py", line 538, in run_forever
#       self._run_once()
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\asyncio\base_events.py", line 1782, in _run_once
#       handle._run()
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\asyncio\events.py", line 88, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\ioloop.py", line 690, in <lambda>
#       lambda f: self._run_callback(functools.partial(callback, future))
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\ioloop.py", line 743, in _run_callback
#       ret = callback()
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 787, in inner
#       self.run()
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 748, in run
#       yielded = self.gen.send(value)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#       yield gen.maybe_future(dispatch(*args))
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#       yielded = next(result)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#       yield gen.maybe_future(handler(stream, idents, msg))
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#       yielded = next(result)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 545, in execute_request
#       user_expressions, allow_stdin,
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#       yielded = next(result)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#       return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 2858, in run_cell
#       raw_cell, store_history, silent, shell_futures)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 2886, in _run_cell
#       return runner(coro)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3063, in run_cell_async
#       interactivity=interactivity, compiler=compiler, result=result)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3254, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "<ipython-input-6-cf7953a05327>", line 1, in <module>
#       model.evaluate(test_ds)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 1947, in evaluate
#       tmp_logs = self.test_function(iterator)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 1727, in test_function
#       return step_function(self, iterator)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 1713, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 1701, in run_step
#       outputs = model.test_step(data)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 1665, in test_step
#       y_pred = self(x, training=False)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\layers\convolutional\base_conv.py", line 283, in call
#       outputs = self.convolution_op(inputs, self.kernel)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\layers\convolutional\base_conv.py", line 262, in convolution_op
#       name=self.__class__.__name__,
# Node: 'model_7/xception/block1_conv1/Conv2D'
# DNN library is not found.
# 	 [[{{node model_7/xception/block1_conv1/Conv2D}}]] [Op:__inference_test_function_5324]

# %%
path = './clothing-dataset-small-master/test/pants/c8d21106-bbdb-4e8d-83e4-bf3d14e54c16.jpg'

# %%
img = load_img(path, target_size=(299,299))

# %%
import numpy as np

# %%
x = np.array(img)
X = np.array([x])
X.shape
# Out:
# (1, 299, 299, 3)

# %%
X = preprocess_input(X)

# %%
pred = model.predict(X)
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-16-3b72b0b1b4e1> in <module>
# ----> 1 pred = model.predict(X)
#
# c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# UnimplementedError: Graph execution error:
#
# Detected at node 'model_7/xception/block1_conv1/Conv2D' defined at (most recent call last):
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\runpy.py", line 193, in _run_module_as_main
#       "__main__", mod_spec)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\runpy.py", line 85, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\traitlets\config\application.py", line 664, in launch_instance
#       app.start()
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelapp.py", line 597, in start
#       self.io_loop.start()
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\platform\asyncio.py", line 149, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\asyncio\base_events.py", line 538, in run_forever
#       self._run_once()
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\asyncio\base_events.py", line 1782, in _run_once
#       handle._run()
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\asyncio\events.py", line 88, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\ioloop.py", line 690, in <lambda>
#       lambda f: self._run_callback(functools.partial(callback, future))
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\ioloop.py", line 743, in _run_callback
#       ret = callback()
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 787, in inner
#       self.run()
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 748, in run
#       yielded = self.gen.send(value)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#       yield gen.maybe_future(dispatch(*args))
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#       yielded = next(result)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#       yield gen.maybe_future(handler(stream, idents, msg))
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#       yielded = next(result)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 545, in execute_request
#       user_expressions, allow_stdin,
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#       yielded = next(result)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#       return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 2858, in run_cell
#       raw_cell, store_history, silent, shell_futures)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 2886, in _run_cell
#       return runner(coro)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3063, in run_cell_async
#       interactivity=interactivity, compiler=compiler, result=result)
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3254, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "C:\Users\tuto\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "<ipython-input-14-3b72b0b1b4e1>", line 1, in <module>
#       pred = model.predict(X)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 2253, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 2041, in predict_function
#       return step_function(self, iterator)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 2027, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 2015, in run_step
#       outputs = model.predict_step(data)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 1983, in predict_step
#       return self(x, training=False)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\layers\convolutional\base_conv.py", line 283, in call
#       outputs = self.convolution_op(inputs, self.kernel)
#     File "c:\Users\tuto\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\layers\convolutional\base_conv.py", line 262, in convolution_op
#       name=self.__class__.__name__,
# Node: 'model_7/xception/block1_conv1/Conv2D'
# DNN library is not found.
# 	 [[{{node model_7/xception/block1_conv1/Conv2D}}]] [Op:__inference_predict_function_6358]

# %%
classes =['dress',
 'hat',
 'longsleeve',
 'outwear',
 'pants',
 'shirt',
 'shoes',
 'shorts',
 'skirt',
 't-shirt']

# %%
dict(zip(classes,pred[0]))
